# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_admission_record_dirty.csv')

# %%
df.head()
# Out:
#       Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0  Shehroz  24.0  Female                  50.0                   68.90
# 1    Waqar  21.0  Female                  99.0                   60.73
# 2   Bushra  17.0    Male                  89.0                     NaN
# 3    Aliya  17.0    Male                  55.0                   85.29
# 4    Bilal  20.0    Male                  65.0                   61.13
#
#         City Admission Status
# 0     Quetta         Rejected
# 1    Karachi              NaN
# 2  Islamabad         Accepted
# 3    Karachi         Rejected
# 4     Lahore              NaN

# %%
df.shape
# Out:
# (157, 7)

# %% [markdown]
# ![image.png](attachment:6d22ee33-836b-4fcc-8bdb-f03cb4b3442f.png)

# %% [markdown]
# ![image.png](attachment:4b0d71d8-689a-4ea7-80fa-f8a084ea3230.png)

# %% [markdown]
# ![image.png](attachment:6d2379a7-6414-441d-9322-0ca4cca1b156.png)

# %% [markdown]
# ![image.png](attachment:38fbee9b-53c4-4c2e-960a-64685e38dce9.png)
