# %% [markdown]
# ![image.png](attachment:f7ebf1b6-c5f5-447a-822a-826af78105af.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"D:\DATA SCIENCE\My machine learnings\datasets\train.csv", usecols=['GarageQual','FireplaceQu','SalePrice']) ## Use 'r' for raw string to avoid issues with backslashes

# %% [markdown]
# ### 1. Selecting only particular columns that i want

# %%
df.head(3)
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
df['GarageQual'].isnull().sum()
# Out:
# np.int64(81)

# %%
#df[df['GarageQual'].isnull()].sum()
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [raw]
# The error in your original code: df[df['GarageQual'].isnull()].sum() was trying to sum the entire dataframe where the column 'GarageQual' had null values. This will give an error if your dataframe has non numeric columns. The correct approach is to sum the boolean series that is returned by the isnull() method.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.kdeplot(df[df['GarageQual'] == 'TA']['SalePrice'], label="Houses with TA", fill=True, color="red")
sns.kdeplot(df[df['GarageQual'].isnull()]['SalePrice'], label="Houses with NA", fill=True, color="blue")

plt.title('GarageQual')
plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde', ax=ax)

df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with TA', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
temp = df[df['GarageQual']=='TA']['SalePrice']

# %%
df['GarageQual'].fillna('TA', inplace=True)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_4020\1818999247.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageQual'].fillna('TA', inplace=True)

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %% [raw]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(8, 5))
# sns.kdeplot(df[df['GarageQual'] == 'TA']['SalePrice'], label="Houses with TA", fill=True, color="red")
# sns.kdeplot(df[df['GarageQual'].isnull()]['SalePrice'], label="Houses with NA", fill=True, color="blue")
#
# plt.title('GarageQual')
# plt.legend()
# plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['GarageQual'] == 'TA']['SalePrice'].plot(kind='kde', ax=ax, color='red')


lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')
# add title
plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# np.int64(690)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde', ax=ax)

df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with Gd', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
temp = df[df['FireplaceQu']=='Gd']['SalePrice']

# %%
df['FireplaceQu'].fillna('Gd', inplace=True)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_4020\3912738894.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FireplaceQu'].fillna('Gd', inplace=True)

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['FireplaceQu'] == 'Gd']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_train)
# Out:
# D:\DATA SCIENCE\My machine learnings\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
X_train
# Out:
# array([['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ...,
#        ['Gd', 'TA'],
#        ['Gd', 'TA'],
#        ['TA', 'TA']], shape=(1168, 2), dtype=object)

# %%
imputer.statistics_
# Out:
# array(['Gd', 'TA'], dtype=object)
