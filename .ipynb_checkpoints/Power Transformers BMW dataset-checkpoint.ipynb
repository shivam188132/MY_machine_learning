# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BMW_Data.csv')

# %%
df.sample(3)
# Out:
#             Date  Adj_Close      Close       High        Low       Open  \
# 1996  2004-07-05  17.080114  35.750000  35.939999  35.650002  35.680000
# 2405  2006-01-27  17.965551  36.919998  37.320000  36.590000  37.220001
# 6406  2021-11-04  72.591278  89.989998  91.440002  89.220001  90.000000
#
#        Volume
# 1996  1152235
# 2405  3600423
# 6406  1405533

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Date  Adj_Close      Close       High        Low       Open  \
# 0    1996-11-08   8.100290  18.171000  18.209999  18.171000  18.209999
# 1    1996-11-11   8.078445  18.122000  18.200001  18.082001  18.190001
# 2    1996-11-12   8.139520  18.259001  18.327999  18.091999  18.160999
# 3    1996-11-13   8.126592  18.230000  18.344000  18.190001  18.344000
# 4    1996-11-14   8.152893  18.289000  18.289000  18.132000  18.205000
# ...         ...        ...        ...        ...        ...        ...
# 7207 2024-12-19  77.279999  77.279999  78.379997  76.900002  77.080002
# 7208 2024-12-20  77.580002  77.580002  77.860001  76.120003  76.699997
# 7209 2024-12-23  76.940002  76.940002  77.680000  76.260002  77.620003
# 7210 2024-12-27  78.339996  78.339996  78.459999  76.739998  76.879997
# 7211 2024-12-30  78.980003  78.980003  79.040001  77.839996  77.919998
#
#        Volume
# 0      767000
# 1      260000
# 2     1066000
# 3      793000
# 4      351000
# ...       ...
# 7207  1297262
# 7208  2000177
# 7209   642208
# 7210   958948
# 7211   456155
#
# [7212 rows x 7 columns]

# %%
df.describe()
# Out:
#                                 Date    Adj_Close        Close         High  \
# count                           7212  7212.000000  7212.000000  7212.000000
# mean   2010-11-05 03:40:13.976705536    36.020199    56.427535    57.111143
# min              1996-11-08 00:00:00     8.065074    17.040001    17.815001
# 25%              2003-10-07 18:00:00    16.443254    34.457500    34.900002
# 50%              2010-10-19 12:00:00    26.329212    49.372501    50.094999
# 75%              2017-11-22 06:00:00    53.329208    79.332500    80.105000
# max              2024-12-30 00:00:00   108.059044   122.599998   123.750000
# std                              NaN    23.641099    25.245886    25.415148
#
#                Low         Open        Volume
# count  7212.000000  7212.000000  7.212000e+03
# mean     55.720695    56.446728  2.107946e+06
# min      16.000000    17.280001  0.000000e+00
# 25%      33.887500    34.465001  1.194308e+06
# 50%      48.752501    49.267500  1.793778e+06
# 75%      78.342497    79.379997  2.636572e+06
# max     120.349998   123.300003  2.871954e+07
# std      25.055661    25.252263  1.467180e+06

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['Low','Date']),df['Low'],test_size=0.2,random_state=42)

# %%
X_train
# Out:
#        Adj_Close       Close        High        Open   Volume
# 2534   19.659340   39.770000   40.830002   40.450001  2491695
# 911    14.822226   33.250000   33.250000   32.700001  1432750
# 6530   64.516624   79.980003   79.980003   78.209999  1725794
# 5714   48.083359   69.410004   69.989998   69.610001  1964372
# 6818  105.959068  112.519997  113.000000  112.680000   808875
# ...          ...         ...         ...         ...      ...
# 3772   33.504574   62.380001   63.689999   62.849998  2449543
# 5191   55.445034   87.000000   87.040001   86.650002  1077436
# 5226   55.221985   86.650002   87.019997   86.000000  1105107
# 5390   57.830719   87.220001   87.900002   86.589996  1955585
# 860    12.036094   27.000000   27.350000   26.620001  1432859
#
# [5769 rows x 5 columns]

# %%
X_train.describe()
# Out:
#          Adj_Close        Close         High         Open        Volume
# count  5769.000000  5769.000000  5769.000000  5769.000000  5.769000e+03
# mean     36.188636    56.660029    57.339746    56.673593  2.100956e+06
# std      23.616929    25.277506    25.443116    25.274171  1.484979e+06
# min       8.065074    17.040001    17.955000    17.650000  0.000000e+00
# 25%      16.463795    34.470001    34.930000    34.500000  1.195629e+06
# 50%      27.762934    50.080002    50.770000    50.049999  1.787865e+06
# 75%      53.460503    79.519997    80.250000    79.529999  2.619743e+06
# max     108.059044   122.599998   123.750000   123.300003  2.871954e+07

# %%
X_train = X_train[X_train.select_dtypes(include='number').columns]+ 0.0001

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
#my function to cheque positive value in the column of a dataframe
def positive_values_check(x):
    # Check if x is a DataFrame or Series
    if isinstance(x, pd.DataFrame):
        df = x
    elif isinstance(x, pd.Series):
        df = pd.DataFrame(x)  # Convert Series to DataFrame for uniform handling
    else:
        raise ValueError("Input must be a DataFrame or Series.")
    
    result = {}
    for col in df.columns:
        positives = (df[col] > 0).sum()
        negatives = (df[col] < 0).sum()
        zeros = (df[col] == 0).sum()
        result[col] = {'Positive': positives, 'Negative': negatives, 'Zero': zeros}
    return pd.DataFrame(result)

# %%
# Pass only a data frame
positive_values_check(X_train['Volume'])
# Out:
#           Volume
# Negative       0
# Positive    5769
# Zero           0

# %%
def Power_Transformer(model):
    
    # Initialize PowerTransformer objects
    pt = PowerTransformer(method='box-cox')
    pt2 = PowerTransformer(method='yeo-johnson')
    
    # Apply PowerTransformers
    X_train_trf = pt.fit_transform(X_train)
    X_train_trf2 = pt2.fit_transform(X_train)

    # Fit the passed model
    model.fit(X_train_trf2, y_train)  # Using Yeo-Johnson transformation in this example
    
    # Predict using the passed model
    y_pred = model.predict(X_test)

    # Calculate cross-validation score using the passed model
    cross_val = np.mean(cross_val_score(model, X_train_trf2, y_train, scoring='r2'))

    # Print evaluation results
    print(f"R² Score from Cross Validation: {cross_val}")

    return y_pred, cross_val

# %%
lr = LinearRegression()
# Call the function with a specific model (e.g., lr3)
y_pred, cross_val = Power_Transformer(lr3)
print(y_pred, cross_val)
# Out:
# R² Score from Cross Validation: 0.9786222372574581
# [ -319384.81897964  -823614.43130204 -1861142.95273864 ...
#  -1162194.23128311 -1634819.94659698 -1965711.46271503] 0.9786222372574581
# C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
y_test
# Out:
# 308     25.211000
# 381     37.069000
# 5716    69.680000
# 2312    36.930000
# 251     25.270000
#           ...
# 2903    39.020000
# 4581    88.550003
# 6434    88.220001
# 5547    84.459999
# 4955    72.139999
# Name: Low, Length: 1443, dtype: float64
